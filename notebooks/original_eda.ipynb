# %% [markdown]
# ## Importando bibliotecas utilizadas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Definindo variáveis

# %%
DATA_PATH = "../data/transformed/transformed_data.csv"

# %% [markdown]
# ## Conhecendo os dados

# %%
df = pd.read_csv(DATA_PATH)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_voluntario       277 non-null    str
#  1   cor_pele            277 non-null    str
#  2   cor_olhos           277 non-null    str
#  3   cor_cabelo_15_anos  277 non-null    str
#  4   rs1426654           256 non-null    str
#  5   rs6058017           237 non-null    str
#  6   rs1800404           234 non-null    str
#  7   rs16891982          139 non-null    str
# dtypes: str(8)
# memory usage: 17.4 KB

# %%
df.columns
# Out:
# Index(['id_voluntario', 'cor_pele', 'cor_olhos', 'cor_cabelo_15_anos',
#        'rs1426654', 'rs6058017', 'rs1800404', 'rs16891982'],
#       dtype='str')

# %%
df.cor_olhos.unique()
# Out:
# <StringArray>
# ['Castanho', 'Verde', 'Preto', 'Azul']
# Length: 4, dtype: str

# %% [markdown]
# ## Plotando gráficos simples

# %% [markdown]
# ### Distribuição de cores de pele

# %%
distribution = df['cor_pele'].value_counts()
x = distribution.index
y = distribution.values
color = ['red', 'blue', 'green', 'yellow', 'purple']

plt.bar(x, y, color=color)
plt.xlabel('Cor da pele')
plt.ylabel('Qtd de indivíduos')
plt.title('Distribuição da cor de pele na mostra de gente')

plt.show()

# %% [markdown]
# ### Distribuição de cores de cabelo

# %%
distribution = df['cor_cabelo_15_anos'].value_counts()
x = distribution.index
y = distribution.values
color = ['blue', 'red', 'yellow', 'purple', 'green']

plt.bar(x, y, color=color)
plt.xlabel('Cor do cabelo aos 15 anos')
plt.ylabel('Qtd de indivíduos')
plt.title('Distribuição da cor de cabelo na mostra de gente')

plt.show()

# %% [markdown]
# ### Distribuição de cores de olhos

# %%
distribution = df['cor_olhos'].value_counts()
x = distribution.index
y = distribution.values
color = ['green', 'red', 'yellow', 'purple', 'blue']

plt.figure(figsize=(10, 6))
plt.bar(x, y, color=color)
plt.xlabel('Combinação dos alelos')
plt.ylabel('Qtd de indivíduos')
plt.title('Distribuição da cor dos olhos na mostra de gente')
plt.show()

# %% [markdown]
# ### Distribuição do genótipo de polimorfismo rs1426654

# %%
distribution = df['rs1426654'].value_counts()
x = distribution.index
y = distribution.values
color = ['green', 'red', 'yellow', 'purple', 'blue']

plt.figure(figsize=(10, 6))
plt.bar(x, y, color=color)
plt.xlabel('Combinação dos alelos')
plt.ylabel('Qtd de ocorrências')
plt.title('Distribuição do genótipo de polimorfismo rs1426654')
plt.show()

# %% [markdown]
# ### Distribuição do genótipo de polimorfismo rs6058017

# %%
distribution = df['rs6058017'].value_counts()
x = distribution.index
y = distribution.values
color = ['green', 'red', 'yellow', 'purple', 'blue']

plt.figure(figsize=(10, 6))
plt.bar(x, y, color=color)
plt.xlabel('Combinação dos alelos')
plt.ylabel('Qtd de ocorrências')
plt.title('Distribuição do genótipo de polimorfismo rs6058017')
plt.show()

# %% [markdown]
# ### Distribuição do genótipo de polimorfismo rs1800404

# %%
distribution = df['rs1800404'].value_counts()
x = distribution.index
y = distribution.values
color = ['green', 'red', 'yellow', 'purple', 'blue']

plt.figure(figsize=(10, 6))
plt.bar(x, y, color=color)
plt.xlabel('Combinação dos alelos')
plt.ylabel('Qtd de ocorrências')
plt.title('Distribuição do genótipo de polimorfismo rs1800404')
plt.show()

# %% [markdown]
# ### Distribuição do genótipo de polimorfismo rs16891982

# %%
distribution = df['rs16891982'].value_counts()
x = distribution.index
y = distribution.values
color = ['green', 'red', 'yellow', 'purple', 'blue']

plt.figure(figsize=(10, 6))
plt.bar(x, y, color=color)
plt.xlabel('Combinação dos alelos')
plt.ylabel('Qtd de ocorrências')
plt.title('Distribuição do genótipo de polimorfismo rs16891982')
plt.show()
